# %%
import pandas as pd

# %%
# Make a reference to the books.csv file path
csv_path = "databases/umc-database.csv"

# Import the books.csv file as a DataFrame
umc = pd.read_csv(csv_path, encoding="utf-8")
umc
# Out:
#                                   title release_date  movie_score  \
# 0                              Iron Man    4/14/2008           93
# 1                   The Incredible Hulk    6/12/2008           67
# 2                            Iron Man 2     5/7/2010           73
# 3                                  Thor     5/6/2011           77
# 4    Captain America: The First Avenger    6/22/2011           80
# 5                          The Avengers     5/4/2012           92
# 6                            Iron Man 3     5/3/2013           79
# 7                  Thor: The Dark World    11/8/2013           67
# 8   Captain America: The Winter Soldier     4/4/2014           90
# 9               Guardians of the Galaxy     6/1/2014           91
# 10              Avengers: Age of Ultron     4/1/2015           75
# 11                              Ant-Man    7/17/2015           83
# 12           Captain America: Civil War     5/6/2016           91
# ...
