# %% [markdown]
# # PROJECT MCU - Data Analysis
# ## Ana Morales, Nick Cresta, Eric Dowd, Marcus Guerrier

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests

# %%
#Import Final_df.csv

final_df = pd.read_csv('output_data/final_df.csv')

#Show
final_df.head(25)
# Out:
#        IMDbID                                Title  Year     Released  \
# 0   tt0371746                             Iron Man  2008  02 May 2008
# 1   tt0800080                  The Incredible Hulk  2008  13 Jun 2008
# 2   tt1228705                           Iron Man 2  2010  07 May 2010
# 3   tt0800369                                 Thor  2011  06 May 2011
# 4   tt0458339   Captain America: The First Avenger  2011  22 Jul 2011
# 5   tt0848228                         The Avengers  2012  04 May 2012
# 6   tt1300854                           Iron Man 3  2013  03 May 2013
# 7   tt1981115                 Thor: The Dark World  2013  08 Nov 2013
# 8   tt1843866  Captain America: The Winter Soldier  2014  04 Apr 2014
# 9   tt2015381              Guardians of the Galaxy  2014  01 Aug 2014
# 10  tt2395427              Avengers: Age of Ultron  2015  01 May 2015
# 11  tt0478970                              Ant-Man  2015  17 Jul 2015
# 12  tt3498820           Captain America: Civil War  2016  06 May 2016
# 13  tt1211837                       Doctor Strange  2016  04 Nov 2016
# 14  tt3896198       Guardians of the Galaxy Vol. 2  2017  05 May 2017
# 15  tt2250912               Spider-Man: Homecoming  2017  07 Jul 2017
# 16  tt3501632                       Thor: Ragnarok  2017  03 Nov 2017
# 17  tt1825683                        Black Panther  2018  16 Feb 2018
# 18  tt4154756               Avengers: Infinity War  2018  27 Apr 2018
# 19  tt5095030                 Ant-Man and the Wasp  2018  06 Jul 2018
# 20  tt4154664                       Captain Marvel  2019  08 Mar 2019
# 21  tt4154796                    Avengers: Endgame  2019  26 Apr 2019
# 22  tt6320628            Spider-Man: Far from Home  2019  02 Jul 2019
#
#     Tomatometer  Metascore  IMDb # of IMDb Votes       Budget  \
# 0            93         79   7.9         930,966  140000000.0
# 1            67         61   6.7         430,679  150000000.0
# 2            73         57   7.0         716,181  200000000.0
# 3            77         57   7.0         740,509  150000000.0
# 4            80         66   6.9         732,650  140000000.0
# 5            92         69   8.0       1,252,715  220000000.0
# 6            79         62   7.2         748,737  200000000.0
# 7            67         54   6.9         590,538  170000000.0
# 8            90         70   7.7         728,693  170000000.0
# 9            91         76   8.0       1,035,000  170000000.0
# 10           75         66   7.3         731,508  250000000.0
# 11           83         64   7.3         563,285  130000000.0
# 12           91         75   7.8         655,365  250000000.0
# 13           89         72   7.5         589,860  165000000.0
# 14           84         67   7.6         562,796  200000000.0
# 15           92         73   7.4         504,737  175000000.0
# 16           93         74   7.9         577,552  180000000.0
# 17           96         88   7.3         617,338  200000000.0
# 18           85         68   8.4         819,170  321000000.0
# 19           88         70   7.1         303,351  162000000.0
# 20           78         64   6.9         432,789  160000000.0
# 21           94         78   8.4         787,075  356000000.0
# 22           90         69   7.5         315,435  160000000.0
#
#     Opening Weekend Sales  Domestic Gross  International Gross  \
# 0               148431129       318604126            266762121
# 1               174921744       134806913            128620638
# 2               167701822       312433331            311500000
# 3               152646352       181030624            268295994
# 20    Anna Boden, Ryan Fleck
# 21  Anthony Russo, Joe Russo
# 22                 Jon Watts
#
#                                                Awards
# 0   Nominated for 2 Oscars. Another 22 wins & 70 n...
# 1                             1 win & 10 nominations.
# 2   Nominated for 1 Oscar. Another 7 wins & 43 nom...
# 3                            5 wins & 30 nominations.
# 4                            4 wins & 46 nominations.
# 5   Nominated for 1 Oscar. Another 38 wins & 79 no...
# 6   Nominated for 1 Oscar. Another 20 wins & 62 no...
# 7                            3 wins & 21 nominations.
# 8   Nominated for 1 Oscar. Another 5 wins & 50 nom...
# 9   Nominated for 2 Oscars. Another 52 wins & 100 ...
# 10                           8 wins & 47 nominations.
# 11  Nominated for 1 BAFTA Film Award. Another 4 wi...
# 12                          16 wins & 68 nominations.
# 13  Nominated for 1 Oscar. Another 20 wins & 66 no...
# 14  Nominated for 1 Oscar. Another 15 wins & 57 no...
# 15                           7 wins & 10 nominations.
# 16                           6 wins & 50 nominations.
# 17  Won 3 Oscars. Another 110 wins & 268 nominations.
# 18  Nominated for 1 Oscar. Another 46 wins & 75 no...
# 19                                    19 nominations.
# 20                           8 wins & 48 nominations.
# 21  Nominated for 1 Oscar. Another 68 wins & 104 n...
# 22                          10 wins & 22 nominations.

# %% [markdown]
# # Charts for Our Data

# %%
#Total Box Office Revenue by Release Date (Line Chart)

# Get data for our "Release Date" and "Worldwide Gross"
x_axis = final_df['Released']
y_axis = final_df['Worldwide Gross']
# Show the line plot
plt.plot(x_axis, y_axis)
plt.title("Total Box Office Revenue by Release Date ", fontsize=18)
plt.xlabel("Release Date")
plt.ylabel("Worldwide Gross (In USD Billions)")
plt.xticks(rotation='90')
plt.grid()

#Export as PNG
plt.savefig("output_data/box_office_by_release.png")

#Show Line Graph
plt.show()

# %%
#Critic Ratings (Bar Chart)

#Create a bar chart for Rotten Tomatoes and Metacritic
x_axis = final_df['Title']
rotten_tomato = final_df["Tomatometer"]
meta_score = final_df["Metascore"]
imdb = final_df["IMDb"]

#Create Bar Chart
plt.bar(x_axis, rotten_tomato, color='r', alpha=0.5, align="center", label="Rotten Tomatoes")
plt.bar(x_axis, meta_score, color='b', alpha=0.5, align="center", label="Metascore")

#Labels and Formatting
plt.xticks(rotation='90')
plt.title("Critic Ratings (Source: Rotten Tomatoes and Metacritic)")
plt.xlabel("Movie Title")
plt.ylabel("Critic Score")
plt.legend(loc="best")
plt.grid(axis="y")

#Export as PNG
plt.savefig("output_data/RT_and_MC.png")

#Show Figure
plt.show()

# %%
#Create Bar Chart for IMDb
plt.bar(x_axis, imdb, color='y', alpha=0.5, align="center", label="IMDb")
plt.xticks(rotation='90')

#Labels 
plt.xlabel("Movie Title")
plt.ylabel("IMDb Score")
plt.title("IMDb Scores for Each Film")
plt.grid(axis="y")

#Export as PNG
plt.savefig("output_data/IMDbScores.png")

#Show our Bar Graph
plt.show()

# %%
#Measure Profitability (Budget vs Worldwide)

#Do A side-by-side-by-side

profitability = final_df["Worldwide Gross"]- final_df["Budget"]
mr_worldwide = final_df["Worldwide Gross"]
budget = final_df["Budget"]

plt.bar(x_axis, mr_worldwide, color='g', alpha=0.7, align="center", label="WorldWide Gross")
plt.bar(x_axis, budget, color='r', alpha=1, align="center", label="Overall Budget")
#plt.bar(x_axis, profitability, color='g', alpha=1, align="center")
plt.xticks(rotation='90')

#Go back to put Labels
plt.title("Worldwide Gross vs. Budget")


#Legend
plt.legend(loc="best")
plt.ylabel("Worldwide Gross in USD Billions")
plt.xlabel("Movie Title")
plt.grid(axis="y")


#Export as PNG
plt.savefig("output_data/WorldwideVBudget.png")

#Show our Bar Graph
plt.show()

# %%
#Opening Box Office Numbers (Chronologically)

#Create Variable
opening = final_df["Opening Weekend Sales"]

#Create Line Plot
plt.plot(x_axis, opening, color='g')

#Create Labels and Formatting
plt.xticks(rotation='90')
plt.title("Opening Box Office Gross in Chronological Order")
plt.ylabel("Opening Weekend Sales(In USD Hundred Millions)")
plt.xlabel("Movie Title")
plt.grid()

#Export as PNG
plt.savefig("output_data/OpeningBoxOffice.png")

#Show Plot
plt.show()

# %%
#Domestic vs International Trend
domestic = final_df["Domestic Gross"]
international = final_df["International Gross"]

#Create Line Plot
plt.plot(x_axis, domestic, color='b', label="Domestic Gross")
plt.plot(x_axis, international, color='r', label = "International Gross")

#Create Label
plt.xticks(rotation='90')
plt.xlabel("Movie Title")
plt.title("Domestic Gross vs. International Gross")
plt.ylabel("Gross by USD Billions")

#Create Legend
plt.legend(loc="best")
plt.grid()
#Export as PNG
plt.savefig("output_data/DomesticVInternational.png")

#Show Plot
plt.show()

# %%
#Critic Vs Box Office (Scatter Plot)
from scipy.stats import linregress
import scipy.stats as sts

#Reiterate Variables
rotten_tomato = final_df["Tomatometer"]
mr_worldwide = final_df["Worldwide Gross"]

#Perform Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(rotten_tomato, mr_worldwide)
regress_values = rotten_tomato * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Correlation Calculation (Nick came up with adding this)
correlation = sts.pearsonr(rotten_tomato, mr_worldwide)

#Create Scatter Plot
plt.scatter(rotten_tomato, mr_worldwide, facecolor='r',edgecolors="g", s=rotten_tomato)
plt.plot(rotten_tomato, regress_values, "b-")
plt.annotate(line_eq,(70,2500000000),fontsize=15,color="red")

#Create Labels
plt.title("Critical Reception (Tomatometer) vs Worldwide Box Office")
plt.xlabel("Tomatomater Score (Source: Rotten Tomatoes)")
plt.ylabel("Worldwide Box Office by USD Billions")
plt.grid()


#Export as PNG
plt.savefig("output_data/CriticalReceptionVWorldwide.png")


#Print Correlation
print(f'The correlation coefficient between our Rotten Tomatoes scores and the Worldwide Gross is {round(correlation[0],2)}')
plt.show()
# Out:
# The correlation coefficient between our Rotten Tomatoes scores and the Worldwide Gross is 0.37

# %%
#Max Theater Release

#Define Variable
tothe_max = final_df["Widest Theater Release"]

#Make The Plot
plt.plot(x_axis, tothe_max, color='c')
plt.xticks(rotation='90')
plt.ylabel("# of Theaters")
plt.title("Widest Theater Release for Each Film")
plt.xlabel("Movie Title")
plt.grid()

#Export as PNG
plt.savefig("output_data/WidestTheaterRelease.png")

#Show our Line graph
plt.show()
